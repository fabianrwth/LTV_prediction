# %% [markdown]
# # Importing required libraries

# %%
import matplotlib
import pandas as pd
import numpy as np
import math
from numpy import argmax
import sys
from IPython.display import display
import warnings
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import cohen_kappa_score

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate

import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

from tensorflow.keras.utils import plot_model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import callbacks

from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks
import numpy as np
import time
import statistics


# library options
# %matplotlib inline
pd.options.display.max_columns = None
warnings.filterwarnings('ignore')

# %%
# Monte Carlo Dropout Layer
class MonteCarloDropout(keras.layers.Dropout):
    def call(self, inputs):
        return super().call(inputs, training=True)

# %% [markdown]
# # Read in the Train and Test data

# %%
X_train = np.array(pd.read_parquet('data/X_train.parquet')).astype('float')
X_test = np.array(pd.read_parquet('data/X_test.parquet')).astype('float')

y_test_class = np.array(pd.read_parquet('data/y_test.parquet')['sum_payments_package_key_ltv_class'])
y_train_class = np.array(pd.read_parquet('data/y_train.parquet')['sum_payments_package_key_ltv_class'])                        
#y_test_class = np.array(pd.read_parquet('data/y_test.parquet')['sum_payments_package_key_ltv_class'].apply(lambda x: 0 if x == 'low' else 1 if x == "medium" else 2 if x == "high" else -1)).astype('float')
#y_train_class = np.array(pd.read_parquet('data/y_train.parquet')['sum_payments_package_key_ltv_class'].apply(lambda x: 0 if x == 'low' else 1 if x == "medium" else 2 if x == "high" else -1)).astype('float')
y_test_reg = np.array(pd.read_parquet('data/y_test.parquet')['sum_payments_package_key_ltv']).astype('float')
y_train_reg = np.array(pd.read_parquet('data/y_train.parquet')['sum_payments_package_key_ltv']).astype('float')
n_class = 3

# %% [markdown]
# # Check Data before Modelling

# %%
print('Training Features Shape:', X_train.shape)
print('Testing Features Shape:', X_test.shape)
print('Training Labels Classification Shape:', y_train_class.shape)
print('Testing Labels Classification Shape:', y_test_class.shape)
# Out:
# Training Features Shape: (111791, 180)
# Testing Features Shape: (27948, 180)
# Training Labels Classification Shape: (111791,)
# Testing Labels Classification Shape: (27948,)

# %% [markdown]
# # Hyperparameter Tuning

# %%
def model_builder(hp):
    model = keras.Sequential()

    # layer 01
    layer_01 = hp.Choice('layer_01', values = ['False','True'])
    if layer_01:
        units_01 = hp.Int('units_01', min_value=64, max_value=1024, step=32)
        activation_01 = hp.Choice('activation_01', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_01 = hp.Choice('kernel_01', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_01, activation = activation_01, kernel_initializer=kernel_initializer_01, input_shape = (X_train.shape[1],)))
    
    batch_01 = hp.Choice('batch_01', values = ['False','True'])
    if batch_01:
        model.add(BatchNormalization())
    
    drop_01 = hp.Choice('drop_01', values = ['False','drop','Monte'])
    if drop_01 == 'drop':
        dropout_01 = hp.Float('dropout_01', min_value=0.1, max_value=0.6, step=0.1)
        model.add(Dropout(dropout_01))
    elif drop_01 == 'Monte':
        monte_01 = hp.Float('monte_01', min_value=0.1, max_value=0.6, step=0.1)
        model.add(MonteCarloDropout(monte_01))
    
    # layer 02
    layer_02 = hp.Choice('layer_02', values = ['False','True'])
    if layer_02:
        units_02 = hp.Int('units_02', min_value = 32, max_value = 512, step=32)
        activation_02 = hp.Choice('activation_02', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_02 = hp.Choice('kernel_02', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_02, activation = activation_02, kernel_initializer=kernel_initializer_02))
    
    batch_02 = hp.Choice('batch_02', values = ['False','True'])
    if batch_02:
        model.add(BatchNormalization())
        
    drop_02 = hp.Choice('drop_02', values = ['False','drop','Monte'])
    if drop_02:
        dropout_02 = hp.Float('dropout_02', min_value=0.1, max_value=0.6, step=0.1)
        model.add(Dropout(dropout_02))
    elif drop_02 == 'Monte':
        monte_02 = hp.Float('monte_02', min_value=0.1, max_value=0.6, step=0.1)
        model.add(MonteCarloDropout(monte_02))
    
    # layer 03
    layer_03 = hp.Choice('layer_03', values = ['False','True'])
    if layer_03:
        units_03 = hp.Int('units_03', min_value = 32, max_value = 512, step=32)
        activation_03 = hp.Choice('activation_03', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_03 = hp.Choice('kernel_03', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_03, activation = activation_03, kernel_initializer=kernel_initializer_03))
    
    drop_03 = hp.Choice('drop_03', values = ['False','drop','Monte'])
    if drop_03:
        dropout_03 = hp.Float('dropout_03', min_value=0.1, max_value=0.6, step=0.1)
        model.add(Dropout(dropout_03))
    elif drop_03 == 'Monte':
        monte_03 = hp.Float('monte_03', min_value=0.1, max_value=0.6, step=0.1)
        model.add(MonteCarloDropout(monte_03))
    
    batch_03 = hp.Choice('batch_03', values = ['False','True'])
    if batch_03:
        model.add(BatchNormalization())
    
    # layer 04
    layer_04 = hp.Choice('layer_04', values = ['False','True'])
    if layer_04:
        units_04 = hp.Int('units_04', min_value = 16, max_value = 512, step=32)
        activation_04 = hp.Choice('activation_04', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_04 = hp.Choice('kernel_04', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_04, activation = activation_04, kernel_initializer=kernel_initializer_04))
    
    drop_04 = hp.Choice('drop_04', values = ['False','drop','Monte'])
    if drop_04:
        dropout_04 = hp.Float('dropout_04', min_value=0.1, max_value=0.6, step=0.1)
        model.add(Dropout(dropout_04))
    elif drop_04 == 'Monte':
        monte_04 = hp.Float('monte_04', min_value=0.1, max_value=0.6, step=0.1)
        model.add(MonteCarloDropout(monte_04))
        
    batch_04 = hp.Choice('batch_04', values = ['False','True'])
    if batch_04:
        model.add(BatchNormalization())
    
    # layer 05
    layer_05 = hp.Choice('layer_05', values = ['False','True'])
    if layer_05:
        units_05 = hp.Int('units_05', min_value = 16, max_value = 256, step=32)
        activation_05 = hp.Choice('activation_05', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_05 = hp.Choice('kernel_05', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_05, activation = activation_05, kernel_initializer=kernel_initializer_05))
    
    drop_05 = hp.Choice('drop_05', values = ['False','drop','Monte'])
    if drop_05:
        dropout_05 = hp.Float('dropout_05', min_value=0.1, max_value=0.6, step=0.1)
        model.add(Dropout(dropout_05))
    elif drop_05 == 'Monte':
        monte_05 = hp.Float('monte_05', min_value=0.1, max_value=0.6, step=0.1)
        model.add(MonteCarloDropout(monte_05))
        
    batch_05 = hp.Choice('batch_05', values = ['False','True'])
    if batch_05:
        model.add(BatchNormalization())
    
    # layer 06
    layer_06 = hp.Choice('layer_06', values = ['False','True'])
    if layer_06:
        units_06 = hp.Int('units_06', min_value = 4, max_value = 16, step=4)
        activation_06 = hp.Choice('activation_06', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_06 = hp.Choice('kernel_06', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_06, activation = activation_06, kernel_initializer=kernel_initializer_06))
        
    # layer 07
    layer_07 = hp.Choice('layer_07', values = ['False','True'])
    if layer_07:
        units_07 = hp.Int('units_07', min_value = 4, max_value = 16, step=4)
        activation_07 = hp.Choice('activation_07', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_07 = hp.Choice('kernel_07', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_07, activation = activation_07, kernel_initializer=kernel_initializer_07))    
    
    # layer 08
    layer_08 = hp.Choice('layer_08', values = ['False','True'])
    if layer_08:
        units_08 = hp.Int('units_08', min_value = 4, max_value = 16, step=4)
        activation_08 = hp.Choice('activation_08', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_08 = hp.Choice('kernel_08', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_08, activation = activation_08, kernel_initializer=kernel_initializer_08))
        
    # layer 09
    layer_09 = hp.Choice('layer_06', values = ['False','True'])
    if layer_09:
        units_09 = hp.Int('units_06', min_value = 4, max_value = 16, step=4)
        activation_09 = hp.Choice('activation_09', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_09 = hp.Choice('kernel_09', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_09, activation = activation_09, kernel_initializer=kernel_initializer_09))
        
    # layer 10
    layer_10 = hp.Choice('layer_10', values = ['False','True'])
    if layer_10:
        units_10 = hp.Int('units_10', min_value = 4, max_value = 16, step=4)
        activation_10 = hp.Choice('activation_10', values = ['LeakyReLU','relu','sigmoid','tanh'])
        kernel_initializer_10 = hp.Choice('kernel_10', values = ['he_uniform', 'he_normal', 'glorot_uniform', 'glorot_normal'])
        model.add(Dense(units_10, activation = activation_10, kernel_initializer=kernel_initializer_10))
    
    model.add(Dense(n_class, activation='softmax'))
    
    # Tune the learning rate for the optimizer
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_crossentropy','accuracy'])

    return model

# %%
# Choose Tuner Hyperband
tuner = kt.Hyperband(model_builder,
                     objective = 'sparse_categorical_crossentropy',
                     max_epochs = 40,
                     factor = 6,
                     project_name = 'MLP_Classification_withGradient_01')

stop_early = callbacks.EarlyStopping(monitor='accuracy', patience=7)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./MLP_Classification_withGradient_01/oracle.json
# INFO:tensorflow:Reloading Tuner from ./MLP_Classification_withGradient_01/tuner0.json

# %%
tuner.search(X_train, y_train_class, epochs=100, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print('The hyperparameter search is complete. The optimal model is:')
print(best_hps)
# Out:
# INFO:tensorflow:Oracle triggered exit
# The hyperparameter search is complete. The optimal model is:
# <keras_tuner.engine.hyperparameters.HyperParameters object at 0x7f92b2baf8e0>

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./MLP_Classification_withGradient_01
# Showing 10 best trials
# Objective(name='sparse_categorical_crossentropy', direction='min')
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 800
# activation_01: sigmoid
# kernel_01: glorot_uniform
# batch_01: True
# drop_01: False
# layer_02: False
# units_02: 96
# activation_02: sigmoid
# kernel_02: glorot_normal
# batch_02: False
# drop_02: Monte
# dropout_02: 0.2
# layer_03: True
# units_03: 416
# activation_03: LeakyReLU
# kernel_03: he_normal
# drop_03: drop
# dropout_03: 0.4
# batch_03: True
# layer_04: True
# units_04: 240
# activation_04: LeakyReLU
# kernel_04: he_normal
# drop_04: False
# dropout_04: 0.30000000000000004
# batch_04: True
# layer_05: False
# units_05: 208
# activation_05: relu
# kernel_05: he_normal
# drop_05: False
# dropout_05: 0.2
# batch_05: True
# layer_06: False
# units_06: 12
# activation_06: relu
# kernel_06: glorot_uniform
# layer_07: True
# units_07: 8
# activation_07: LeakyReLU
# kernel_07: glorot_normal
# layer_08: True
# units_08: 16
# activation_08: relu
# kernel_08: he_normal
# activation_09: sigmoid
# kernel_09: he_normal
# layer_10: True
# units_10: 16
# activation_10: relu
# kernel_10: glorot_normal
# learning_rate: 0.001
# monte_01: 0.2
# dropout_01: 0.2
# tuner/epochs: 40
# tuner/initial_epoch: 7
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: bd5e62d219e97557c6dee2c263dec493
# Score: 0.3237343728542328
# Trial summary
# Hyperparameters:
# layer_01: True
# units_01: 640
# activation_01: tanh
# kernel_01: he_normal
# batch_01: True
# drop_01: drop
# layer_02: True
# units_02: 64
# activation_02: sigmoid
# kernel_02: he_normal
# batch_02: True
# drop_02: False
# dropout_02: 0.30000000000000004
# layer_03: False
# units_03: 384
# activation_03: sigmoid
# kernel_03: glorot_normal
# drop_03: Monte
# dropout_03: 0.5
# batch_03: False
# layer_04: False
# units_04: 432
# activation_04: relu
# kernel_04: he_normal
# drop_04: drop
# dropout_04: 0.5
# batch_04: False
# layer_05: True
# units_05: 112
# activation_05: relu
# kernel_05: he_uniform
# drop_05: drop
# dropout_05: 0.2
# batch_05: False
# layer_06: False
# units_06: 8
# activation_06: sigmoid
# kernel_06: he_normal
# layer_07: False
# units_07: 4
# activation_07: LeakyReLU
# kernel_07: he_normal
# layer_08: True
# units_08: 16
# activation_08: LeakyReLU
# kernel_08: he_normal
# activation_09: relu
# kernel_09: glorot_uniform
# layer_10: True
# units_10: 8
# activation_10: relu
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.4
# tuner/epochs: 40
# tuner/initial_epoch: 7
# tuner/bracket: 2
# tuner/round: 2
# dropout_01: 0.1
# tuner/trial_id: 9e6d55417f138d475e2f8d6b8fad62fd
# Score: 0.34136152267456055
# Trial summary
# Hyperparameters:
# layer_01: True
# units_01: 896
# activation_01: tanh
# kernel_01: he_uniform
# batch_01: False
# drop_01: drop
# layer_02: False
# units_02: 352
# activation_02: relu
# kernel_02: glorot_uniform
# batch_02: False
# drop_02: False
# dropout_02: 0.5
# layer_03: True
# units_03: 224
# activation_03: tanh
# kernel_03: glorot_uniform
# drop_03: drop
# dropout_03: 0.5
# batch_03: True
# layer_04: True
# units_04: 304
# activation_04: LeakyReLU
# kernel_04: he_uniform
# drop_04: Monte
# dropout_04: 0.4
# batch_04: False
# layer_05: True
# units_05: 208
# activation_05: LeakyReLU
# kernel_05: he_uniform
# drop_05: False
# dropout_05: 0.6
# batch_05: True
# layer_06: True
# units_06: 4
# activation_06: relu
# kernel_06: glorot_normal
# layer_07: False
# units_07: 4
# activation_07: sigmoid
# kernel_07: glorot_normal
# layer_08: False
# units_08: 12
# activation_08: LeakyReLU
# kernel_08: glorot_uniform
# activation_09: LeakyReLU
# kernel_09: he_uniform
# layer_10: True
# units_10: 8
# activation_10: sigmoid
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.30000000000000004
# dropout_01: 0.30000000000000004
# tuner/epochs: 40
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.3474804759025574
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 896
# activation_01: relu
# kernel_01: he_normal
# batch_01: False
# drop_01: drop
# layer_02: True
# units_02: 320
# activation_02: relu
# kernel_02: glorot_normal
# batch_02: False
# drop_02: drop
# dropout_02: 0.2
# layer_03: False
# units_03: 320
# activation_03: relu
# kernel_03: glorot_uniform
# drop_03: Monte
# dropout_03: 0.1
# batch_03: True
# layer_04: True
# units_04: 400
# activation_04: tanh
# kernel_04: glorot_normal
# drop_04: drop
# dropout_04: 0.6
# batch_04: True
# layer_05: False
# units_05: 240
# activation_05: sigmoid
# kernel_05: he_normal
# drop_05: False
# dropout_05: 0.4
# batch_05: False
# layer_06: True
# units_06: 8
# activation_06: relu
# kernel_06: he_uniform
# layer_07: False
# units_07: 12
# activation_07: LeakyReLU
# kernel_07: glorot_normal
# layer_08: True
# units_08: 8
# activation_08: sigmoid
# kernel_08: glorot_normal
# activation_09: sigmoid
# kernel_09: glorot_uniform
# layer_10: True
# units_10: 4
# activation_10: tanh
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.4
# dropout_01: 0.30000000000000004
# tuner/epochs: 40
# tuner/initial_epoch: 7
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 24f5c88030e7202317a1577561a85b26
# Score: 0.3724689483642578
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 704
# activation_01: tanh
# kernel_01: glorot_normal
# batch_01: False
# drop_01: drop
# layer_02: True
# units_02: 256
# activation_02: tanh
# kernel_02: glorot_uniform
# batch_02: True
# drop_02: False
# dropout_02: 0.4
# layer_03: True
# units_03: 480
# activation_03: tanh
# kernel_03: he_normal
# drop_03: False
# dropout_03: 0.30000000000000004
# batch_03: False
# layer_04: True
# units_04: 304
# activation_04: tanh
# kernel_04: he_normal
# drop_04: drop
# dropout_04: 0.1
# batch_04: True
# layer_05: True
# units_05: 112
# activation_05: relu
# kernel_05: glorot_normal
# drop_05: Monte
# dropout_05: 0.30000000000000004
# batch_05: True
# layer_06: True
# units_06: 12
# activation_06: LeakyReLU
# kernel_06: glorot_normal
# layer_07: False
# units_07: 4
# activation_07: LeakyReLU
# kernel_07: glorot_uniform
# layer_08: True
# units_08: 8
# activation_08: relu
# kernel_08: glorot_uniform
# activation_09: tanh
# kernel_09: glorot_normal
# layer_10: False
# units_10: 12
# activation_10: relu
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.30000000000000004
# dropout_01: 0.2
# tuner/epochs: 40
# tuner/initial_epoch: 7
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 561379e62a55e46cbcfead964f0d6a23
# Score: 0.37369588017463684
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 800
# activation_01: sigmoid
# kernel_01: glorot_uniform
# batch_01: True
# drop_01: False
# layer_02: False
# units_02: 96
# activation_02: sigmoid
# kernel_02: glorot_normal
# batch_02: False
# drop_02: Monte
# dropout_02: 0.2
# layer_03: True
# units_03: 416
# activation_03: LeakyReLU
# kernel_03: he_normal
# drop_03: drop
# dropout_03: 0.4
# batch_03: True
# layer_04: True
# units_04: 240
# activation_04: LeakyReLU
# kernel_04: he_normal
# drop_04: False
# dropout_04: 0.30000000000000004
# batch_04: True
# layer_05: False
# units_05: 208
# activation_05: relu
# kernel_05: he_normal
# drop_05: False
# dropout_05: 0.2
# batch_05: True
# layer_06: False
# units_06: 12
# activation_06: relu
# kernel_06: glorot_uniform
# layer_07: True
# units_07: 8
# activation_07: LeakyReLU
# kernel_07: glorot_normal
# layer_08: True
# units_08: 16
# activation_08: relu
# kernel_08: he_normal
# activation_09: sigmoid
# kernel_09: he_normal
# layer_10: True
# units_10: 16
# activation_10: relu
# kernel_10: glorot_normal
# learning_rate: 0.001
# monte_01: 0.2
# dropout_01: 0.2
# tuner/epochs: 7
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.3851391673088074
# Trial summary
# Hyperparameters:
# layer_01: True
# units_01: 640
# activation_01: tanh
# kernel_01: he_normal
# batch_01: True
# drop_01: drop
# layer_02: True
# units_02: 64
# activation_02: sigmoid
# kernel_02: he_normal
# batch_02: True
# drop_02: False
# dropout_02: 0.30000000000000004
# layer_03: False
# units_03: 384
# activation_03: sigmoid
# kernel_03: glorot_normal
# drop_03: Monte
# dropout_03: 0.5
# batch_03: False
# layer_04: False
# units_04: 432
# activation_04: relu
# kernel_04: he_normal
# drop_04: drop
# dropout_04: 0.5
# batch_04: False
# layer_05: True
# units_05: 112
# activation_05: relu
# kernel_05: he_uniform
# drop_05: drop
# dropout_05: 0.2
# batch_05: False
# layer_06: False
# units_06: 8
# activation_06: sigmoid
# kernel_06: he_normal
# layer_07: False
# units_07: 4
# activation_07: LeakyReLU
# kernel_07: he_normal
# layer_08: True
# units_08: 16
# activation_08: LeakyReLU
# kernel_08: he_normal
# activation_09: relu
# kernel_09: glorot_uniform
# layer_10: True
# units_10: 8
# activation_10: relu
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.4
# tuner/epochs: 7
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# dropout_01: 0.1
# tuner/trial_id: aeb71ff759e509564196da7d04ec2dcf
# Score: 0.3935086727142334
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 704
# activation_01: tanh
# kernel_01: glorot_normal
# batch_01: False
# drop_01: drop
# layer_02: True
# units_02: 256
# activation_02: tanh
# kernel_02: glorot_uniform
# batch_02: True
# drop_02: False
# dropout_02: 0.4
# layer_03: True
# units_03: 480
# activation_03: tanh
# kernel_03: he_normal
# drop_03: False
# dropout_03: 0.30000000000000004
# batch_03: False
# layer_04: True
# units_04: 304
# activation_04: tanh
# kernel_04: he_normal
# drop_04: drop
# dropout_04: 0.1
# batch_04: True
# layer_05: True
# units_05: 112
# activation_05: relu
# kernel_05: glorot_normal
# drop_05: Monte
# dropout_05: 0.30000000000000004
# batch_05: True
# layer_06: True
# units_06: 12
# activation_06: LeakyReLU
# kernel_06: glorot_normal
# layer_07: False
# units_07: 4
# activation_07: LeakyReLU
# kernel_07: glorot_uniform
# layer_08: True
# units_08: 8
# activation_08: relu
# kernel_08: glorot_uniform
# activation_09: tanh
# kernel_09: glorot_normal
# layer_10: False
# units_10: 12
# activation_10: relu
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.30000000000000004
# dropout_01: 0.2
# tuner/epochs: 7
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 2a10b169e7b377ac5c908e2179eff026
# Score: 0.3952399492263794
# Trial summary
# Hyperparameters:
# layer_01: True
# units_01: 160
# activation_01: tanh
# kernel_01: he_uniform
# batch_01: True
# drop_01: False
# layer_02: False
# units_02: 64
# activation_02: LeakyReLU
# kernel_02: glorot_uniform
# batch_02: False
# drop_02: Monte
# dropout_02: 0.30000000000000004
# layer_03: False
# units_03: 352
# activation_03: LeakyReLU
# kernel_03: he_normal
# drop_03: drop
# dropout_03: 0.1
# batch_03: False
# layer_04: True
# units_04: 496
# activation_04: sigmoid
# kernel_04: he_uniform
# drop_04: Monte
# dropout_04: 0.5
# batch_04: False
# layer_05: False
# units_05: 144
# activation_05: relu
# kernel_05: glorot_normal
# drop_05: False
# dropout_05: 0.5
# batch_05: False
# layer_06: False
# units_06: 8
# activation_06: sigmoid
# kernel_06: glorot_normal
# layer_07: True
# units_07: 4
# activation_07: LeakyReLU
# kernel_07: he_uniform
# layer_08: True
# units_08: 8
# activation_08: LeakyReLU
# kernel_08: he_uniform
# activation_09: tanh
# kernel_09: he_normal
# layer_10: False
# units_10: 16
# activation_10: tanh
# kernel_10: he_uniform
# learning_rate: 0.001
# monte_01: 0.5
# dropout_01: 0.2
# tuner/epochs: 7
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: a22d392d71e302d38435e6fa0edda23e
# Score: 0.3957579731941223
# Trial summary
# Hyperparameters:
# layer_01: False
# units_01: 896
# activation_01: relu
# kernel_01: he_normal
# batch_01: False
# drop_01: drop
# layer_02: True
# units_02: 320
# activation_02: relu
# kernel_02: glorot_normal
# batch_02: False
# drop_02: drop
# dropout_02: 0.2
# layer_03: False
# units_03: 320
# activation_03: relu
# kernel_03: glorot_uniform
# drop_03: Monte
# dropout_03: 0.1
# batch_03: True
# layer_04: True
# units_04: 400
# activation_04: tanh
# kernel_04: glorot_normal
# drop_04: drop
# dropout_04: 0.6
# batch_04: True
# layer_05: False
# units_05: 240
# activation_05: sigmoid
# kernel_05: he_normal
# drop_05: False
# dropout_05: 0.4
# batch_05: False
# layer_06: True
# units_06: 8
# activation_06: relu
# kernel_06: he_uniform
# layer_07: False
# units_07: 12
# activation_07: LeakyReLU
# kernel_07: glorot_normal
# layer_08: True
# units_08: 8
# activation_08: sigmoid
# kernel_08: glorot_normal
# activation_09: sigmoid
# kernel_09: glorot_uniform
# layer_10: True
# units_10: 4
# activation_10: tanh
# kernel_10: he_normal
# learning_rate: 0.001
# monte_01: 0.4
# dropout_01: 0.30000000000000004
# tuner/epochs: 7
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.3974074721336365

# %%
# Build the model with the optimal hyperparameters and train it on the data for 100 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train_class,validation_split=0.33, epochs = 100)
# Out:
# Epoch 1/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.5418 - sparse_categorical_crossentropy: 0.5418 - accuracy: 0.7823 - val_loss: 0.4083 - val_sparse_categorical_crossentropy: 0.4083 - val_accuracy: 0.8430
# Epoch 2/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.4464 - sparse_categorical_crossentropy: 0.4464 - accuracy: 0.8239 - val_loss: 0.3970 - val_sparse_categorical_crossentropy: 0.3970 - val_accuracy: 0.8433
# Epoch 3/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.4225 - sparse_categorical_crossentropy: 0.4225 - accuracy: 0.8325 - val_loss: 0.3989 - val_sparse_categorical_crossentropy: 0.3989 - val_accuracy: 0.8411
# Epoch 4/100
# 2341/2341 [==============================] - 10s 4ms/step - loss: 0.4154 - sparse_categorical_crossentropy: 0.4154 - accuracy: 0.8351 - val_loss: 0.3777 - val_sparse_categorical_crossentropy: 0.3777 - val_accuracy: 0.8537
# Epoch 5/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.4037 - sparse_categorical_crossentropy: 0.4037 - accuracy: 0.8407 - val_loss: 0.3833 - val_sparse_categorical_crossentropy: 0.3833 - val_accuracy: 0.8514
# Epoch 6/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.4017 - sparse_categorical_crossentropy: 0.4017 - accuracy: 0.8424 - val_loss: 0.3845 - val_sparse_categorical_crossentropy: 0.3845 - val_accuracy: 0.8415
# Epoch 7/100
# 2341/2341 [==============================] - 16s 7ms/step - loss: 0.3944 - sparse_categorical_crossentropy: 0.3944 - accuracy: 0.8437 - val_loss: 0.3727 - val_sparse_categorical_crossentropy: 0.3727 - val_accuracy: 0.8521
# Epoch 8/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3919 - sparse_categorical_crossentropy: 0.3919 - accuracy: 0.8438 - val_loss: 0.3729 - val_sparse_categorical_crossentropy: 0.3729 - val_accuracy: 0.8532
# Epoch 9/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.3892 - sparse_categorical_crossentropy: 0.3892 - accuracy: 0.8440 - val_loss: 0.3754 - val_sparse_categorical_crossentropy: 0.3754 - val_accuracy: 0.8515
# Epoch 10/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3866 - sparse_categorical_crossentropy: 0.3866 - accuracy: 0.8458 - val_loss: 0.3749 - val_sparse_categorical_crossentropy: 0.3749 - val_accuracy: 0.8532
# Epoch 11/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3841 - sparse_categorical_crossentropy: 0.3841 - accuracy: 0.8459 - val_loss: 0.3707 - val_sparse_categorical_crossentropy: 0.3707 - val_accuracy: 0.8550
# Epoch 12/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.3820 - sparse_categorical_crossentropy: 0.3820 - accuracy: 0.8464 - val_loss: 0.3687 - val_sparse_categorical_crossentropy: 0.3687 - val_accuracy: 0.8558
# Epoch 13/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3800 - sparse_categorical_crossentropy: 0.3800 - accuracy: 0.8487 - val_loss: 0.3679 - val_sparse_categorical_crossentropy: 0.3679 - val_accuracy: 0.8561
# Epoch 14/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.3787 - sparse_categorical_crossentropy: 0.3787 - accuracy: 0.8476 - val_loss: 0.3670 - val_sparse_categorical_crossentropy: 0.3670 - val_accuracy: 0.8541
# Epoch 15/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.3762 - sparse_categorical_crossentropy: 0.3762 - accuracy: 0.8495 - val_loss: 0.3675 - val_sparse_categorical_crossentropy: 0.3675 - val_accuracy: 0.8555
# Epoch 16/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3753 - sparse_categorical_crossentropy: 0.3753 - accuracy: 0.8491 - val_loss: 0.3691 - val_sparse_categorical_crossentropy: 0.3691 - val_accuracy: 0.8543
# Epoch 17/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.3725 - sparse_categorical_crossentropy: 0.3725 - accuracy: 0.8503 - val_loss: 0.3686 - val_sparse_categorical_crossentropy: 0.3686 - val_accuracy: 0.8567
# Epoch 18/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.3721 - sparse_categorical_crossentropy: 0.3721 - accuracy: 0.8505 - val_loss: 0.3670 - val_sparse_categorical_crossentropy: 0.3670 - val_accuracy: 0.8558
# Epoch 19/100
# 2341/2341 [==============================] - 16s 7ms/step - loss: 0.3695 - sparse_categorical_crossentropy: 0.3695 - accuracy: 0.8517 - val_loss: 0.3696 - val_sparse_categorical_crossentropy: 0.3696 - val_accuracy: 0.8531
# Epoch 20/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.3684 - sparse_categorical_crossentropy: 0.3684 - accuracy: 0.8519 - val_loss: 0.3694 - val_sparse_categorical_crossentropy: 0.3694 - val_accuracy: 0.8564
# Epoch 21/100
# 2341/2341 [==============================] - 13s 5ms/step - loss: 0.3658 - sparse_categorical_crossentropy: 0.3658 - accuracy: 0.8529 - val_loss: 0.3712 - val_sparse_categorical_crossentropy: 0.3712 - val_accuracy: 0.8542
# Epoch 22/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.3633 - sparse_categorical_crossentropy: 0.3633 - accuracy: 0.8535 - val_loss: 0.3734 - val_sparse_categorical_crossentropy: 0.3734 - val_accuracy: 0.8563
# Epoch 23/100
# 2341/2341 [==============================] - 15s 6ms/step - loss: 0.3621 - sparse_categorical_crossentropy: 0.3621 - accuracy: 0.8549 - val_loss: 0.3751 - val_sparse_categorical_crossentropy: 0.3751 - val_accuracy: 0.8544
# Epoch 24/100
# 2341/2341 [==============================] - 13s 5ms/step - loss: 0.3566 - sparse_categorical_crossentropy: 0.3566 - accuracy: 0.8562 - val_loss: 0.3719 - val_sparse_categorical_crossentropy: 0.3719 - val_accuracy: 0.8525
# Epoch 25/100
# 2341/2341 [==============================] - 13s 5ms/step - loss: 0.3564 - sparse_categorical_crossentropy: 0.3564 - accuracy: 0.8566 - val_loss: 0.3750 - val_sparse_categorical_crossentropy: 0.3750 - val_accuracy: 0.8531
# Epoch 26/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3535 - sparse_categorical_crossentropy: 0.3535 - accuracy: 0.8570 - val_loss: 0.3901 - val_sparse_categorical_crossentropy: 0.3901 - val_accuracy: 0.8513
# Epoch 27/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3479 - sparse_categorical_crossentropy: 0.3479 - accuracy: 0.8596 - val_loss: 0.3801 - val_sparse_categorical_crossentropy: 0.3801 - val_accuracy: 0.8537
# Epoch 28/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3458 - sparse_categorical_crossentropy: 0.3458 - accuracy: 0.8603 - val_loss: 0.3924 - val_sparse_categorical_crossentropy: 0.3924 - val_accuracy: 0.8521
# Epoch 29/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3436 - sparse_categorical_crossentropy: 0.3436 - accuracy: 0.8614 - val_loss: 0.3906 - val_sparse_categorical_crossentropy: 0.3906 - val_accuracy: 0.8497
# Epoch 30/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3360 - sparse_categorical_crossentropy: 0.3360 - accuracy: 0.8645 - val_loss: 0.3917 - val_sparse_categorical_crossentropy: 0.3917 - val_accuracy: 0.8446
# Epoch 31/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3354 - sparse_categorical_crossentropy: 0.3354 - accuracy: 0.8648 - val_loss: 0.3978 - val_sparse_categorical_crossentropy: 0.3978 - val_accuracy: 0.8480
# Epoch 32/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3303 - sparse_categorical_crossentropy: 0.3303 - accuracy: 0.8678 - val_loss: 0.4001 - val_sparse_categorical_crossentropy: 0.4001 - val_accuracy: 0.8452
# Epoch 33/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3244 - sparse_categorical_crossentropy: 0.3244 - accuracy: 0.8698 - val_loss: 0.4051 - val_sparse_categorical_crossentropy: 0.4051 - val_accuracy: 0.8419
# Epoch 34/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3214 - sparse_categorical_crossentropy: 0.3214 - accuracy: 0.8715 - val_loss: 0.4104 - val_sparse_categorical_crossentropy: 0.4104 - val_accuracy: 0.8391
# Epoch 35/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.3158 - sparse_categorical_crossentropy: 0.3158 - accuracy: 0.8743 - val_loss: 0.4317 - val_sparse_categorical_crossentropy: 0.4317 - val_accuracy: 0.8248
# Epoch 36/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.3129 - sparse_categorical_crossentropy: 0.3129 - accuracy: 0.8761 - val_loss: 0.4331 - val_sparse_categorical_crossentropy: 0.4331 - val_accuracy: 0.8219
# Epoch 37/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.3054 - sparse_categorical_crossentropy: 0.3054 - accuracy: 0.8793 - val_loss: 0.4403 - val_sparse_categorical_crossentropy: 0.4403 - val_accuracy: 0.8263
# Epoch 38/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2988 - sparse_categorical_crossentropy: 0.2988 - accuracy: 0.8821 - val_loss: 0.4380 - val_sparse_categorical_crossentropy: 0.4380 - val_accuracy: 0.8341
# Epoch 39/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2970 - sparse_categorical_crossentropy: 0.2970 - accuracy: 0.8839 - val_loss: 0.4466 - val_sparse_categorical_crossentropy: 0.4466 - val_accuracy: 0.8260
# Epoch 40/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2914 - sparse_categorical_crossentropy: 0.2914 - accuracy: 0.8855 - val_loss: 0.4459 - val_sparse_categorical_crossentropy: 0.4459 - val_accuracy: 0.8284
# Epoch 41/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2847 - sparse_categorical_crossentropy: 0.2847 - accuracy: 0.8894 - val_loss: 0.4727 - val_sparse_categorical_crossentropy: 0.4727 - val_accuracy: 0.8225
# Epoch 42/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2807 - sparse_categorical_crossentropy: 0.2807 - accuracy: 0.8913 - val_loss: 0.4824 - val_sparse_categorical_crossentropy: 0.4824 - val_accuracy: 0.8104
# Epoch 43/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.2757 - sparse_categorical_crossentropy: 0.2757 - accuracy: 0.8936 - val_loss: 0.4702 - val_sparse_categorical_crossentropy: 0.4702 - val_accuracy: 0.8236
# Epoch 44/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.2701 - sparse_categorical_crossentropy: 0.2701 - accuracy: 0.8955 - val_loss: 0.4902 - val_sparse_categorical_crossentropy: 0.4902 - val_accuracy: 0.8178
# Epoch 45/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.2630 - sparse_categorical_crossentropy: 0.2630 - accuracy: 0.8983 - val_loss: 0.4900 - val_sparse_categorical_crossentropy: 0.4900 - val_accuracy: 0.8277
# Epoch 46/100
# 2341/2341 [==============================] - 13s 5ms/step - loss: 0.2590 - sparse_categorical_crossentropy: 0.2590 - accuracy: 0.9007 - val_loss: 0.5139 - val_sparse_categorical_crossentropy: 0.5139 - val_accuracy: 0.8046
# Epoch 47/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.2538 - sparse_categorical_crossentropy: 0.2538 - accuracy: 0.9028 - val_loss: 0.5347 - val_sparse_categorical_crossentropy: 0.5347 - val_accuracy: 0.8035
# Epoch 48/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.2500 - sparse_categorical_crossentropy: 0.2500 - accuracy: 0.9046 - val_loss: 0.5497 - val_sparse_categorical_crossentropy: 0.5497 - val_accuracy: 0.7824
# Epoch 49/100
# 2341/2341 [==============================] - 15s 6ms/step - loss: 0.2448 - sparse_categorical_crossentropy: 0.2448 - accuracy: 0.9070 - val_loss: 0.5094 - val_sparse_categorical_crossentropy: 0.5094 - val_accuracy: 0.8068
# Epoch 50/100
# 2341/2341 [==============================] - 15s 6ms/step - loss: 0.2392 - sparse_categorical_crossentropy: 0.2392 - accuracy: 0.9090 - val_loss: 0.5397 - val_sparse_categorical_crossentropy: 0.5397 - val_accuracy: 0.8162
# Epoch 51/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.2354 - sparse_categorical_crossentropy: 0.2354 - accuracy: 0.9107 - val_loss: 0.5322 - val_sparse_categorical_crossentropy: 0.5322 - val_accuracy: 0.8157
# Epoch 52/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.2299 - sparse_categorical_crossentropy: 0.2299 - accuracy: 0.9132 - val_loss: 0.5543 - val_sparse_categorical_crossentropy: 0.5543 - val_accuracy: 0.8042
# Epoch 53/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.2273 - sparse_categorical_crossentropy: 0.2273 - accuracy: 0.9150 - val_loss: 0.5779 - val_sparse_categorical_crossentropy: 0.5779 - val_accuracy: 0.7935
# Epoch 54/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.2256 - sparse_categorical_crossentropy: 0.2256 - accuracy: 0.9160 - val_loss: 0.5667 - val_sparse_categorical_crossentropy: 0.5667 - val_accuracy: 0.8089
# Epoch 55/100
# 2341/2341 [==============================] - 11s 5ms/step - loss: 0.2175 - sparse_categorical_crossentropy: 0.2175 - accuracy: 0.9188 - val_loss: 0.5935 - val_sparse_categorical_crossentropy: 0.5935 - val_accuracy: 0.7972
# Epoch 56/100
# 2341/2341 [==============================] - 12s 5ms/step - loss: 0.2119 - sparse_categorical_crossentropy: 0.2119 - accuracy: 0.9217 - val_loss: 0.5945 - val_sparse_categorical_crossentropy: 0.5945 - val_accuracy: 0.8056
# Epoch 57/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.2083 - sparse_categorical_crossentropy: 0.2083 - accuracy: 0.9239 - val_loss: 0.5733 - val_sparse_categorical_crossentropy: 0.5733 - val_accuracy: 0.8121
# Epoch 58/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.2085 - sparse_categorical_crossentropy: 0.2085 - accuracy: 0.9236 - val_loss: 0.5997 - val_sparse_categorical_crossentropy: 0.5997 - val_accuracy: 0.8064
# Epoch 59/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.2039 - sparse_categorical_crossentropy: 0.2039 - accuracy: 0.9243 - val_loss: 0.6387 - val_sparse_categorical_crossentropy: 0.6387 - val_accuracy: 0.7926
# Epoch 60/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.1973 - sparse_categorical_crossentropy: 0.1973 - accuracy: 0.9273 - val_loss: 0.6262 - val_sparse_categorical_crossentropy: 0.6262 - val_accuracy: 0.8026
# Epoch 61/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.1939 - sparse_categorical_crossentropy: 0.1939 - accuracy: 0.9300 - val_loss: 0.6190 - val_sparse_categorical_crossentropy: 0.6190 - val_accuracy: 0.7968
# Epoch 62/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.1897 - sparse_categorical_crossentropy: 0.1897 - accuracy: 0.9311 - val_loss: 0.6138 - val_sparse_categorical_crossentropy: 0.6138 - val_accuracy: 0.7947
# Epoch 63/100
# 2341/2341 [==============================] - 18s 8ms/step - loss: 0.1899 - sparse_categorical_crossentropy: 0.1899 - accuracy: 0.9301 - val_loss: 0.6204 - val_sparse_categorical_crossentropy: 0.6204 - val_accuracy: 0.8183
# Epoch 64/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.1854 - sparse_categorical_crossentropy: 0.1854 - accuracy: 0.9323 - val_loss: 0.6585 - val_sparse_categorical_crossentropy: 0.6585 - val_accuracy: 0.8002
# Epoch 65/100
# 2341/2341 [==============================] - 13s 6ms/step - loss: 0.1819 - sparse_categorical_crossentropy: 0.1819 - accuracy: 0.9340 - val_loss: 0.6388 - val_sparse_categorical_crossentropy: 0.6388 - val_accuracy: 0.8028
# Epoch 66/100
# 2341/2341 [==============================] - 14s 6ms/step - loss: 0.1788 - sparse_categorical_crossentropy: 0.1788 - accuracy: 0.9347 - val_loss: 0.6576 - val_sparse_categorical_crossentropy: 0.6576 - val_accuracy: 0.8074
# Epoch 67/100
# 2341/2341 [==============================] - 22s 9ms/step - loss: 0.1755 - sparse_categorical_crossentropy: 0.1755 - accuracy: 0.9370 - val_loss: 0.6775 - val_sparse_categorical_crossentropy: 0.6775 - val_accuracy: 0.8001
# Epoch 68/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1733 - sparse_categorical_crossentropy: 0.1733 - accuracy: 0.9369 - val_loss: 0.7023 - val_sparse_categorical_crossentropy: 0.7023 - val_accuracy: 0.7922
# Epoch 69/100
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.1701 - sparse_categorical_crossentropy: 0.1701 - accuracy: 0.9386 - val_loss: 0.6837 - val_sparse_categorical_crossentropy: 0.6837 - val_accuracy: 0.7839
# Epoch 70/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1683 - sparse_categorical_crossentropy: 0.1683 - accuracy: 0.9395 - val_loss: 0.6682 - val_sparse_categorical_crossentropy: 0.6682 - val_accuracy: 0.8100
# Epoch 71/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1726 - sparse_categorical_crossentropy: 0.1726 - accuracy: 0.9374 - val_loss: 0.7100 - val_sparse_categorical_crossentropy: 0.7100 - val_accuracy: 0.7931
# Epoch 72/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1642 - sparse_categorical_crossentropy: 0.1642 - accuracy: 0.9409 - val_loss: 0.7270 - val_sparse_categorical_crossentropy: 0.7270 - val_accuracy: 0.7985
# Epoch 73/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1591 - sparse_categorical_crossentropy: 0.1591 - accuracy: 0.9431 - val_loss: 0.7106 - val_sparse_categorical_crossentropy: 0.7106 - val_accuracy: 0.7990
# Epoch 74/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1576 - sparse_categorical_crossentropy: 0.1576 - accuracy: 0.9433 - val_loss: 0.7005 - val_sparse_categorical_crossentropy: 0.7005 - val_accuracy: 0.8094
# Epoch 75/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1564 - sparse_categorical_crossentropy: 0.1564 - accuracy: 0.9443 - val_loss: 0.7692 - val_sparse_categorical_crossentropy: 0.7692 - val_accuracy: 0.7874
# Epoch 76/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1522 - sparse_categorical_crossentropy: 0.1522 - accuracy: 0.9464 - val_loss: 0.7693 - val_sparse_categorical_crossentropy: 0.7693 - val_accuracy: 0.7825
# Epoch 77/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1514 - sparse_categorical_crossentropy: 0.1514 - accuracy: 0.9466 - val_loss: 0.7797 - val_sparse_categorical_crossentropy: 0.7797 - val_accuracy: 0.7893
# Epoch 78/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1498 - sparse_categorical_crossentropy: 0.1498 - accuracy: 0.9467 - val_loss: 0.8059 - val_sparse_categorical_crossentropy: 0.8059 - val_accuracy: 0.7834
# Epoch 79/100
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.1482 - sparse_categorical_crossentropy: 0.1482 - accuracy: 0.9470 - val_loss: 0.7440 - val_sparse_categorical_crossentropy: 0.7440 - val_accuracy: 0.7850
# Epoch 80/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1461 - sparse_categorical_crossentropy: 0.1461 - accuracy: 0.9482 - val_loss: 0.7644 - val_sparse_categorical_crossentropy: 0.7644 - val_accuracy: 0.7926
# Epoch 81/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1429 - sparse_categorical_crossentropy: 0.1429 - accuracy: 0.9495 - val_loss: 0.7028 - val_sparse_categorical_crossentropy: 0.7028 - val_accuracy: 0.7881
# Epoch 82/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1398 - sparse_categorical_crossentropy: 0.1398 - accuracy: 0.9505 - val_loss: 0.7595 - val_sparse_categorical_crossentropy: 0.7595 - val_accuracy: 0.7862
# Epoch 83/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1406 - sparse_categorical_crossentropy: 0.1406 - accuracy: 0.9496 - val_loss: 0.7449 - val_sparse_categorical_crossentropy: 0.7449 - val_accuracy: 0.7956
# Epoch 84/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1350 - sparse_categorical_crossentropy: 0.1350 - accuracy: 0.9522 - val_loss: 0.7638 - val_sparse_categorical_crossentropy: 0.7638 - val_accuracy: 0.7849
# Epoch 85/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1348 - sparse_categorical_crossentropy: 0.1348 - accuracy: 0.9520 - val_loss: 0.8435 - val_sparse_categorical_crossentropy: 0.8435 - val_accuracy: 0.7777
# Epoch 86/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1335 - sparse_categorical_crossentropy: 0.1335 - accuracy: 0.9529 - val_loss: 0.8500 - val_sparse_categorical_crossentropy: 0.8500 - val_accuracy: 0.7693
# Epoch 87/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1281 - sparse_categorical_crossentropy: 0.1281 - accuracy: 0.9546 - val_loss: 0.7833 - val_sparse_categorical_crossentropy: 0.7833 - val_accuracy: 0.8050
# Epoch 88/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1287 - sparse_categorical_crossentropy: 0.1287 - accuracy: 0.9537 - val_loss: 0.8055 - val_sparse_categorical_crossentropy: 0.8055 - val_accuracy: 0.7971
# Epoch 89/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1267 - sparse_categorical_crossentropy: 0.1267 - accuracy: 0.9558 - val_loss: 0.8513 - val_sparse_categorical_crossentropy: 0.8513 - val_accuracy: 0.7939
# Epoch 90/100
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.1265 - sparse_categorical_crossentropy: 0.1265 - accuracy: 0.9554 - val_loss: 0.9425 - val_sparse_categorical_crossentropy: 0.9425 - val_accuracy: 0.7580
# Epoch 91/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1266 - sparse_categorical_crossentropy: 0.1266 - accuracy: 0.9560 - val_loss: 0.8106 - val_sparse_categorical_crossentropy: 0.8106 - val_accuracy: 0.7908
# Epoch 92/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1237 - sparse_categorical_crossentropy: 0.1237 - accuracy: 0.9566 - val_loss: 0.8330 - val_sparse_categorical_crossentropy: 0.8330 - val_accuracy: 0.7977
# Epoch 93/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1228 - sparse_categorical_crossentropy: 0.1228 - accuracy: 0.9575 - val_loss: 0.8698 - val_sparse_categorical_crossentropy: 0.8698 - val_accuracy: 0.7673
# Epoch 94/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1207 - sparse_categorical_crossentropy: 0.1207 - accuracy: 0.9571 - val_loss: 0.9183 - val_sparse_categorical_crossentropy: 0.9183 - val_accuracy: 0.7612
# Epoch 95/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1167 - sparse_categorical_crossentropy: 0.1167 - accuracy: 0.9593 - val_loss: 0.8633 - val_sparse_categorical_crossentropy: 0.8633 - val_accuracy: 0.7840
# Epoch 96/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1182 - sparse_categorical_crossentropy: 0.1182 - accuracy: 0.9586 - val_loss: 0.8938 - val_sparse_categorical_crossentropy: 0.8938 - val_accuracy: 0.7527
# Epoch 97/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1189 - sparse_categorical_crossentropy: 0.1189 - accuracy: 0.9584 - val_loss: 0.8740 - val_sparse_categorical_crossentropy: 0.8740 - val_accuracy: 0.7882
# Epoch 98/100
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.1151 - sparse_categorical_crossentropy: 0.1151 - accuracy: 0.9600 - val_loss: 0.8295 - val_sparse_categorical_crossentropy: 0.8295 - val_accuracy: 0.7893
# Epoch 99/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1143 - sparse_categorical_crossentropy: 0.1143 - accuracy: 0.9597 - val_loss: 0.9069 - val_sparse_categorical_crossentropy: 0.9069 - val_accuracy: 0.7914
# Epoch 100/100
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.1110 - sparse_categorical_crossentropy: 0.1110 - accuracy: 0.9612 - val_loss: 0.8706 - val_sparse_categorical_crossentropy: 0.8706 - val_accuracy: 0.8006

# %%
# Find best epoch during training by observing performance on validation set
val_loss_per_epoch = history.history['val_loss']
best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 14

# %%
start_time = time.time()
hypermodel = tuner.hypermodel.build(best_hps)
print(str(model),"--- %s seconds ---" % ((time.time() - start_time)))

# Retrain the model
#best_epoch
history = hypermodel.fit(X_train, y_train_class,validation_split=0.33, epochs=best_epoch)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f92d16d67f0> --- 0.504896879196167 seconds ---
# Epoch 1/14
# 2341/2341 [==============================] - 31s 12ms/step - loss: 0.5383 - sparse_categorical_crossentropy: 0.5383 - accuracy: 0.7860 - val_loss: 0.4243 - val_sparse_categorical_crossentropy: 0.4243 - val_accuracy: 0.8381
# Epoch 2/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.4451 - sparse_categorical_crossentropy: 0.4451 - accuracy: 0.8225 - val_loss: 0.3887 - val_sparse_categorical_crossentropy: 0.3887 - val_accuracy: 0.8474
# Epoch 3/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.4259 - sparse_categorical_crossentropy: 0.4259 - accuracy: 0.8308 - val_loss: 0.3803 - val_sparse_categorical_crossentropy: 0.3803 - val_accuracy: 0.8523
# Epoch 4/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.4143 - sparse_categorical_crossentropy: 0.4143 - accuracy: 0.8360 - val_loss: 0.3832 - val_sparse_categorical_crossentropy: 0.3832 - val_accuracy: 0.8507
# Epoch 5/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.4071 - sparse_categorical_crossentropy: 0.4071 - accuracy: 0.8382 - val_loss: 0.3802 - val_sparse_categorical_crossentropy: 0.3802 - val_accuracy: 0.8490
# Epoch 6/14
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.4012 - sparse_categorical_crossentropy: 0.4012 - accuracy: 0.8412 - val_loss: 0.3782 - val_sparse_categorical_crossentropy: 0.3782 - val_accuracy: 0.8534
# Epoch 7/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.3953 - sparse_categorical_crossentropy: 0.3953 - accuracy: 0.8419 - val_loss: 0.3743 - val_sparse_categorical_crossentropy: 0.3743 - val_accuracy: 0.8541
# Epoch 8/14
# 2341/2341 [==============================] - 27s 11ms/step - loss: 0.3930 - sparse_categorical_crossentropy: 0.3930 - accuracy: 0.8432 - val_loss: 0.3760 - val_sparse_categorical_crossentropy: 0.3760 - val_accuracy: 0.8536
# Epoch 9/14
# 2341/2341 [==============================] - 26s 11ms/step - loss: 0.3888 - sparse_categorical_crossentropy: 0.3888 - accuracy: 0.8449 - val_loss: 0.3716 - val_sparse_categorical_crossentropy: 0.3716 - val_accuracy: 0.8534
# Epoch 10/14
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.3862 - sparse_categorical_crossentropy: 0.3862 - accuracy: 0.8457 - val_loss: 0.3688 - val_sparse_categorical_crossentropy: 0.3688 - val_accuracy: 0.8511
# Epoch 11/14
# 2341/2341 [==============================] - 27s 12ms/step - loss: 0.3859 - sparse_categorical_crossentropy: 0.3859 - accuracy: 0.8451 - val_loss: 0.3674 - val_sparse_categorical_crossentropy: 0.3674 - val_accuracy: 0.8556
# Epoch 12/14
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.3820 - sparse_categorical_crossentropy: 0.3820 - accuracy: 0.8466 - val_loss: 0.3723 - val_sparse_categorical_crossentropy: 0.3723 - val_accuracy: 0.8510
# Epoch 13/14
# 2341/2341 [==============================] - 28s 12ms/step - loss: 0.3808 - sparse_categorical_crossentropy: 0.3808 - accuracy: 0.8476 - val_loss: 0.3678 - val_sparse_categorical_crossentropy: 0.3678 - val_accuracy: 0.8562
# Epoch 14/14
# 2341/2341 [==============================] - 26s 11ms/step - loss: 0.3777 - sparse_categorical_crossentropy: 0.3777 - accuracy: 0.8487 - val_loss: 0.3674 - val_sparse_categorical_crossentropy: 0.3674 - val_accuracy: 0.8566

# %% [markdown]
# ## Results

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'], color = '#4472C4')
plt.plot(history.history['val_accuracy'], color = '#ED7D31')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.ylim(0.7,0.98)
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('results/DNN_accuracy_Class.png')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'], color = '#4472C4')
plt.plot(history.history['val_loss'], color = '#ED7D31')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.ylim(0,0.95)
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('results/DNN_loss_Class.png')
plt.show()
# Out:
# dict_keys(['loss', 'sparse_categorical_crossentropy', 'accuracy', 'val_loss', 'val_sparse_categorical_crossentropy', 'val_accuracy'])

# %%
#note in kera model.predict() will return predict probabilities
y_pred =  hypermodel.predict(X_test, verbose=0)

prediction_class = []
for i in range(len(y_pred)):
    if y_pred[i][0] > y_pred[i][1] and y_pred[i][0] > y_pred[i][2]:
        prediction_class.append(0)
    if y_pred[i][1] > y_pred[i][0] and y_pred[i][1] > y_pred[i][2]:
        prediction_class.append(1)
    if y_pred[i][2] > y_pred[i][0] and y_pred[i][2] > y_pred[i][1]:
        prediction_class.append(2)

#f1_score(y_test_class, y_pred, average=None)

prediction_class = np.array(prediction_class)
print("F1-Score per Class: %s" % f1_score(y_test_class, prediction_class, average=None)) 
print("F1-Score on Micro average (micro calculates positive and negative values globally): %s" % f1_score(y_test_class, prediction_class, average='micro')) 
print("F1-Score on Macro average (average of each class’s F-1 score): %s" % f1_score(y_test_class, prediction_class, average='macro')) 
print("F1-Score on weighted average: %s" % f1_score(y_test_class, prediction_class, average='weighted')) 
print('______________________________________________________')
print('')
print(classification_report(y_test_class, prediction_class, target_names=['Low','Medium','High']))

ConfusionMatrixDisplay.from_predictions(y_test_class, prediction_class, display_labels=['Low','Medium','High'], xticks_rotation="vertical")
plt.tight_layout()
plt.savefig('results/DNN_Class_Confusion.png')
#plt.tight_layout()
plt.show()
# Out:
# F1-Score per Class: [0.90941105 0.84903356 0.78729511]
# F1-Score on Micro average (micro calculates positive and negative values globally): 0.8495062258480033
# F1-Score on Macro average (average of each class’s F-1 score): 0.848579906878402
# F1-Score on weighted average: 0.8449287145554795
# ______________________________________________________
#
#               precision    recall  f1-score   support
#
#          Low       0.83      1.00      0.91      7494
#       Medium       0.81      0.89      0.85     11267
#         High       0.95      0.67      0.79      9187
#
#     accuracy                           0.85     27948
#    macro avg       0.86      0.86      0.85     27948
# weighted avg       0.86      0.85      0.84     27948

# %%
cohen_kappa = cohen_kappa_score(y_test_class, prediction_class)
cohen_kappa
# Out:
# 0.7711135826450557

# %%
# Print Model Layout:
plot_model(hypermodel, to_file='results/hypermodel_class.png', show_shapes=True)

# %%
eval_result = hypermodel.evaluate(X_test, y_test_class)
print("[test loss, test sparse_categorical_crossentropy,test accuracy]:", eval_result)
# Out:
# 874/874 [==============================] - 4s 4ms/step - loss: 0.3831 - sparse_categorical_crossentropy: 0.3831 - accuracy: 0.8495
# [test loss, test sparse_categorical_crossentropy,test accuracy]: [0.38310545682907104, 0.38310545682907104, 0.8495061993598938]

# %% [markdown]
# # 10-Fold Cross-Validation

# %%
# Define the K-fold Cross Validator

num_folds = 10
kfold = KFold(n_splits=num_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
scores = []


inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train_class, y_test_class), axis=0)

for train, test in kfold.split(inputs, targets):

    best_model = tuner.hypermodel.build(best_hps)

    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    best_model.fit(inputs[train], targets[train], epochs=best_epoch, verbose=0, callbacks = [stop_early])
    score = model.evaluate(inputs[test], targets[test], verbose=0)

    y_pred =  best_model.predict(inputs[test], verbose=0)

    prediction_class = []
    for i in range(len(y_pred)):
        if y_pred[i][0] > y_pred[i][1] and y_pred[i][0] > y_pred[i][2]:
            prediction_class.append(0)
        if y_pred[i][1] > y_pred[i][0] and y_pred[i][1] > y_pred[i][2]:
            prediction_class.append(1)
        if y_pred[i][2] > y_pred[i][0] and y_pred[i][2] > y_pred[i][1]:
            prediction_class.append(2)

    score.append(cohen_kappa_score(targets[test], prediction_class))
    print(f'Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold {fold_no}: {score}')

    #yhat = model.predict(inputs[test])
    #print('MAE: %.3f' % mean_absolute_error(targets[test], yhat))

    #MAE_per_fold.append(mean_absolute_error(targets[test], yhat))
    #loss_per_fold.append(score)
    scores.append(score)
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 1: [0.4884447455406189, 0.4884447455406189, 0.8771289587020874, 0.7756418878819265]
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 2: [0.4747471213340759, 0.4747471213340759, 0.884571373462677, 0.7766457152060419]
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 3: [0.48758751153945923, 0.48758751153945923, 0.8815657496452332, 0.7760310174033865]
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 4: [0.49248170852661133, 0.49248170852661133, 0.8812079429626465, 0.7701095604460695]
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 5: [0.47905293107032776, 0.47905293107032776, 0.8812079429626465, 0.7845679220460923]
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 6: [0.4801712930202484, 0.4801712930202484, 0.8821382522583008, 0.7733470790502995]
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 7: [0.4978239834308624, 0.4978239834308624, 0.8801345229148865, 0.7749641306046454]
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 8: [0.4643622934818268, 0.4643622934818268, 0.884356677532196, 0.7857850344785046]
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 9: [0.47334787249565125, 0.47334787249565125, 0.8827822804450989, 0.778966455298739]
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Score [test loss, test sparse_categorical_crossentropy,test accuracy, cohen kappa score] for fold 10: [0.5237808227539062, 0.5237808227539062, 0.872683048248291, 0.7689074812227575]

# %% [markdown]
# ## Plot Results

# %%
plt.figure(figsize=(20, 8))
#Create the plots
sparse_categorical_crossentropy = []
accuracy = []
cohen = []

for a_tuple in scores:
    sparse_categorical_crossentropy.append(a_tuple[1])
    accuracy.append(a_tuple[2])
    cohen.append(a_tuple[-1])
    
#plt.plot(range(1,len(scores)+1),accuracy, color='blue', label = 'accuracy')
plt.plot(range(1,len(scores)+1),sparse_categorical_crossentropy, color = '#4472C4', label = 'sparse_categorical_crossentropy')
#Create the title, axis description and legend
#plt.title('Results KFOLD Cross-Validation')
plt.ylabel('Crossentropy')
plt.xlabel("Numer of Fold")
#plt.legend()
#plt.grid()
plt.savefig('results/DNN_KFold_Crossentropy.png')
plt.xticks(rotation = 0)
plt.rcParams.update({'font.size': 12})

# %%
plt.figure(figsize=(20, 8))
plt.plot(range(1,len(scores)+1),accuracy, color = '#4472C4', label = 'accuracy')
#plt.plot(range(1,len(scores)+1),sparse_categorical_crossentropy, color='red', label = 'sparse_categorical_crossentropy')
#Create the title, axis description and legend
#plt.title('Results KFOLD Cross-Validation')
plt.ylabel('Accuracy')
plt.xlabel("Numer of Fold")
#plt.legend()
#plt.grid()
plt.xticks(rotation = 0)
plt.savefig('results/DNN_KFold_Accuracy.png')
plt.rcParams.update({'font.size': 12})

# %%
statistics.mean(accuracy)
# Out:
# 0.8807776749134064

# %%
statistics.mean(cohen)
# Out:
# 0.7764966283638463
